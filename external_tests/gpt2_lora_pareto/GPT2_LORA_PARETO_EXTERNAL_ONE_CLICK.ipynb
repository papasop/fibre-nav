# %% [markdown]
# # GPT-2 LoRA-B Pareto external one-click reproduction
#
# Run all cells. No upload is required. This reruns the frozen 8-seed/24-node GPT-2 native-LoRA-B Pareto cohort; it is a same-cohort external reproduction, not an independent new-seed confirmation.

# %%
import subprocess, sys, urllib.request
url = 'https://raw.githubusercontent.com/papasop/neural-fibre-geometry/codex/readme-behaviour-learning-hierarchy/external_tests/gpt2_lora_pareto/COLAB_ONE_CLICK_GPT2_LORA_PARETO.py'
launcher = '/content/COLAB_ONE_CLICK_GPT2_LORA_PARETO.py'
urllib.request.urlretrieve(url, launcher)
subprocess.run([sys.executable, '-u', launcher, '--full'], check=True)
