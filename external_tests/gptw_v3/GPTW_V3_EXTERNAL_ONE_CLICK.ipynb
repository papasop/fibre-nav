# %% [markdown]
# # GPTW-V3 external one-click reproduction
# Select an **A100 GPU** runtime and choose **Runtime → Run all**. No upload is required. This reruns the frozen V3 cohort; it is a reproducibility test, not a new-cohort confirmation.

# %%
import subprocess, sys, urllib.request
url = 'https://raw.githubusercontent.com/papasop/neural-fibre-geometry/v1.5.1-gptw-v3-one-click/external_tests/gptw_v3/COLAB_ONE_CLICK_GPTW_V3.py'
launcher = '/content/COLAB_ONE_CLICK_GPTW_V3.py'
urllib.request.urlretrieve(url, launcher)
subprocess.run([sys.executable, '-u', launcher], check=True)
